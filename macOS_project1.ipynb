# %% [markdown]
# <a href="https://colab.research.google.com/github/contr4l/CoLabBackup/blob/master/macOS_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from matplotlib import plot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9c578191944a> in <module>()
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.plot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.plot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data = pd.read_csv('sample_data/mnist_train_small.csv')

# %%
pd.set_option('max_rows', 10)

# %%
data.describe()
# Out:
#              labels      feature0      feature1      feature2     feature3  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.00000
# mean       5.260400      1.788050      0.294000      0.024850      0.00235
# std       30.828965     17.222191      6.677664      1.638678      0.33234
# min        0.000000      0.000000      0.000000      0.000000      0.00000
# 25%        0.000000      0.000000      0.000000      0.000000      0.00000
# 50%        0.000000      0.000000      0.000000      0.000000      0.00000
# 75%        0.000000      0.000000      0.000000      0.000000      0.00000
# max      255.000000    255.000000    254.000000    172.000000     47.00000
#
#            feature4      feature5      feature6      feature7      feature8  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       0.022300      0.084100      0.521150      2.297150      6.028650
# ...
